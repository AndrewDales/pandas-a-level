# %%
import datareader as datareader
import pandas as pd
import datetime
import pandas_datareader as web
import matplotlib.pyplot as plt
from matplotlib import style

style.use('ggplot')


start = datetime.datetime(2015, 1, 1)
end = datetime.datetime(2021, 6, 11)

df = web.DataReader("AAPL", 'yahoo', start, end)
df.tail()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-06-07  126.320000  124.830002  126.169998  125.900002  71057600.0
# 2021-06-08  128.460007  126.209999  126.599998  126.739998  74403800.0
# 2021-06-09  127.750000  126.519997  127.209999  127.129997  56877900.0
# 2021-06-10  128.190002  125.940002  127.019997  126.110001  71186400.0
# 2021-06-11  127.440002  126.099998  126.529999  127.349998  53522400.0
#
#              Adj Close
# Date
# 2021-06-07  125.900002
# 2021-06-08  126.739998
# 2021-06-09  127.129997
# 2021-06-10  126.110001
# 2021-06-11  127.349998

# %%
df_ema = df['Adj Close'].ewm(halflife=20).mean()
df_ema.tail()
# Out:
# Date
# 2021-06-07    127.123724
# 2021-06-08    127.110653
# 2021-06-09    127.111312
# 2021-06-10    127.077204
# 2021-06-11    127.086496
# Name: Adj Close, dtype: float64

# %%
fig = plt.figure(figsize=(15,10))
df['Adj Close'].plot(label= 'Apple Share Price')
df_ema.plot(label= 'Moving Average')
plt.legend()
